# %%
# !pip install spacy
# !python -m spacy download fr_core_news_md
# Out:
# ...
#      |████████████████████████████████| 85.7MB 87.2MB/s
# ...
#   Created wheel for fr-core-news-md: filename=fr_core_news_md-2.1.0-cp36-none-any.whl size=87463873 sha256=36bd0a67688d50a0d9bb15ec58d322c7867a4176b480061a4e4018c59f95546f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wqjt3wp5/wheels/7e/91/64/f61e597321455d6e42a76abac5736d919a265c31be451cc1ba
# Successfully built fr-core-news-md
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('fr_core_news_md')

# %%
from spacy.lang.fr.examples import sentences 
import fr_core_news_md

nlp = fr_core_news_md.load()
doc = nlp("Grève SNCF/RATP: les prévisions de trafic pour ce mardi très perturbé. Au treizième jour de la grève contre la réforme des retraites, le trafic annoncé doit encore se réduire par rapport à celui de ce lundi. La SNCF annonce en effet un TGV et un Ouigo sur quatre en moyenne, l'axe Atlantique étant particulièrement perturbé, avec seulement un train sur cinq.Comme les jours précédents, les lignes internationales connaissent un trafic difficile, à l'image de l'Eurostar et du Thalys (deux trains sur trois) ou encore du Lyria (un train sur quatre). Les Intercités de nuit ne fonctionnent toujours pas, et seuls 5% des Intercités de jour circulent mardi.")
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)

print("\n")

for entity in doc.ents:
    
    print(entity.text, entity.label_)
# Out:
# Grève SNCF/RATP: les prévisions de trafic pour ce mardi très perturbé. Au treizième jour de la grève contre la réforme des retraites, le trafic annoncé doit encore se réduire par rapport à celui de ce lundi. La SNCF annonce en effet un TGV et un Ouigo sur quatre en moyenne, l'axe Atlantique étant particulièrement perturbé, avec seulement un train sur cinq.Comme les jours précédents, les lignes internationales connaissent un trafic difficile, à l'image de l'Eurostar et du Thalys (deux trains sur trois) ou encore du Lyria (un train sur quatre). Les Intercités de nuit ne fonctionnent toujours pas, et seuls 5% des Intercités de jour circulent mardi.
# Grève NOUN ROOT
# SNCF ADJ amod
# / ADP case
# RATP NOUN nmod
# : PUNCT punct
# les DET det
# prévisions NOUN nmod
# de ADP case
# trafic NOUN nmod
# pour ADP case
# ce DET det
# mardi NOUN nmod
# très ADV advmod
# perturbé ADJ amod
# . PUNCT punct
# Au DET case
# treizième ADJ amod
# jour NOUN obl
# de ADP case
# la DET det
# ...

# %%
from spacy import displacy
sentence_spans = list(doc.sents)

options = {"compact": True, "bg": "#09a3d5",
           "color": "white", "font": "Source Sans Pro"}

displacy.render(doc, style='dep', jupyter=True, options=options)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="1aa6ee071e11445a8cd35b2a7a6b8140-0" class="displacy" width="16850" height="962.0" direction="ltr" style="max-width: none; height: 962.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="872.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Grève</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="872.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">SNCF/</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="872.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">RATP:</tspan>
# ...

# %%
colors = {"ORG": "linear-gradient(90deg, #aa9cfc, #fc9ce7)"}
options = {"ents": ["ORG"], "colors": colors}
displacy.render(doc, style="ent", options=options , jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Grève
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     SNCF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# /
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     RATP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ...

# %%
token1 = nlp("SNCF")
token2 = nlp("RATP")

print(token1.similarity(token2))
# Out:
# 0.0
# /usr/lib/python3.6/runpy.py:193: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   "__main__", mod_spec)

# %%
token1 = nlp("SNCF")
token2 = nlp("Atlantique")

print(token1.similarity(token2))
# Out:
# 0.0777868421719455
